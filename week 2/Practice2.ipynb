# %%
# Input from user
m = float(input("Enter mass in kilograms: "))

# Constant value for the speed of ligth in m/s
c = 299792458

# Calculating energy using Einsteins's equation
energy = m * c ** 2

# Displaying the result
print(f"The energy equivalent to (m) kg of mass is {energy} joules.")
# Out:
# Enter mass in kilograms:  36
# The energy equivalent to (m) kg of mass is 3.2355186434525435e+18 joules.
