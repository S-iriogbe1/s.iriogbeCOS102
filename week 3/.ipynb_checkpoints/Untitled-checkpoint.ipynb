# %%
def swap(x, y):
    global a
    a = "Lawal"
    x,y = y,x
    b = "Chris"
    b = "Edward"
    c = "Lola"
    print(a,b,x,y)
    a = "Mary"
swap("Tina","Tola")
print(a)
# Out:
# Lawal Edward Tola Tina
# Mary
